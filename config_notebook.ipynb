# %%
# This is the common configuration file for all notebooks

# catalogs to mimic medallion architecture
catalog_bronze = "bronze_dev"
catalog_silver = "silver_dev"
catalog_gold = "gold_dev"

# schemas
schema_retail = "global_mart_retail"

# Volume paths
volume_raw = f"/Volumes/{catalog_bronze}/{schema_retail}/raw_data"
f"/Volumes/{catalog}/{schema}/{volume}/"
volume_checkpoint = f"/Volumes/{catalog_bronze}/{schema_retail}/checkpoints"

# Table names
table_orders_bronze = f"{catalog_bronze}.{schema_retail}.orders_bronze"
table_orders_silver = f"{catalog_silver}.{schema_retail}.orders_silver"
