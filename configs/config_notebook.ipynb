# %%
# ======================================================
# Global Configuration – Global Mart Retail Project
# ======================================================

# -------------------------
# Environment
# -------------------------
ENV = "dev"  # dev | test | prod 

# -------------------------
# Catalogs (Medallion)
# -------------------------
CATALOGS = {
    "bronze": f"bronze_{ENV}",
    "silver": f"silver_{ENV}",
    "gold":   f"gold_{ENV}"
}

# -------------------------
# Schema (Business Domain)
# -------------------------
SCHEMA = "global_mart_retail"

# -------------------------
# Volumes
# -------------------------
VOLUMES = {
    "raw_data": f"/Volumes/{CATALOGS['bronze']}/{SCHEMA}/raw_data",
    "checkpoints": f"/Volumes/{CATALOGS['bronze']}/{SCHEMA}/checkpoints"
}

# -------------------------
# Tables
# -------------------------
TABLES = {
    # Bronze
    "orders_bronze": f"{CATALOGS['bronze']}.{SCHEMA}.orders_bronze",

    # Silver
    "orders_silver": f"{CATALOGS['silver']}.{SCHEMA}.orders_silver",

    # Gold
    "orders_gold": f"{CATALOGS['gold']}.{SCHEMA}.orders_gold",
    "dim_customers": f"{CATALOGS['gold']}.{SCHEMA}.dim_customers",
    "dim_products": f"{CATALOGS['gold']}.{SCHEMA}.dim_products",
    "dim_geography": f"{CATALOGS['gold']}.{SCHEMA}.dim_geography",
    "dim_date": f"{CATALOGS['gold']}.{SCHEMA}.dim_date",
    "fact_sales": f"{CATALOGS['gold']}.{SCHEMA}.fact_sales"
}
