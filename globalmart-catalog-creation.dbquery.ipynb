-- %%
--> create bronze catalog
create catalog bronze_dev;

--> create silver catalog
create catalog silver_dev;

--> create gold catalog
create catalog gold_dev;


--> create schemas
create schema bronze_dev.global_mart_retail;
create schema silver_dev.global_mart_retail;
create schema gold_dev.global_mart_retail;

--> create volume inside the global mart retail schema
create volume bronze_dev.global_mart_retail.raw_data;
